# %% [markdown]
# <a href="https://colab.research.google.com/github/Mikchi/website_trust_prediction1/blob/main/website_trust_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Predicting User Trust and Aesthetic Perception from Website Design
#
# **Title:** Predicting User Trust and Aesthetic Perception from Website Design Using Machine Learning.
#
# **Research question:** Can machine learning predict user trust, aesthetics, and usability ratings from visual website design features?

# %% [markdown]
# ## Week 1 - Research background and literature review
#
# **Goal:** learn the basic ideas behind website credibility and first impressions. **Reading and writing only - no coding.**
#
# Topics to read about: human-computer interaction (HCI), website credibility, first impressions in web design, visual complexity, prototypicality, trust and usability.
#
# **Deliverables:** a literature review summary, your research question, and a 5-minute presentation.

# %% [markdown]
# ### Notes: background *(write your answer here)*
#
#
# Write a one-sentence definition for each in your own words:
#
#
# - **Trust (in web design):** How legitimate, secure, and credible a website is
# - **Aesthetics:** How individuals perceive beauty in visuals and artworks
# - **Usability:** How easily and effectively a user can interact with a website
# - **Prototypicality:** How typical a design looks for its category
# - **Visual complexity:** How busy or simple a design looks
#
#
# **What the dataset measures** *(2-3 sentences after reading the dataset overview)*:
# The dataset measures the prototypicality, visual aesthetics, perceived usability, and trustworthiness of websites. By gathering data from varied domains such as commercial banking, online shopping and ecommerce, and universities, the dataset aims so explore the relationship between visual design features and user perceptions across different website categories.
#
#
# **My final research question:** How do visual complexity and prototypicality interact to predict user perceptions of trust, aesthetics, and usability?
#
#
# **3-5 papers I read (title + one key finding each):**
#
#
# **Stanford Web Credibility Project**
# - 46.1% of users' credibility assessments were based on visual design
#
#
# **The role of visual complexity and prototypicality regarding first impression of websites: Working towards understanding aesthetic judgments**
# - Users decide trust before they read a single word
#
#
# **Research gaps I noticed:**
# - The Stanford-Makovsky Web Credibility Study (2002) was methodologically limited by its reliance on self-report surveys, which introduces potential response bias and constrains precision. Tuch et al.'s 2012 study on visual complexity and first impressions was restricted in scope due to it's data collection through a controlled lab study containing only company websites, and therefore fails to evaluate the relationship between visual design features and user perceptions across different website categories.

# %% [markdown]
# ## Setup

# %%
# Install and import the libraries you need.
# TODO

# %% [markdown]
# ![Screenshot 2026-07-12 200638.png](data:image/png;base64,...)

# %%
# (Colab) Mount Google Drive so your files are saved between sessions.
# TODO

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Week 2 - Dataset exploration
#
# **Goal:** load the dataset and understand its structure: the rating variables, the homepage categories (banking, e-commerce, university), and how users evaluated each page.
#
# **Deliverables:** a dataset report and a variable description table.

# %%
# Load the ratings table into a pandas DataFrame.
# TODO

# %% [markdown]
# ![PERMIT ENTRY (2).png](data:image/png;base64,...)

# %%
# Inspect the columns so you know what each variable means.
# TODO

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# How many homepages are there per category (banking / e-commerce / university)?
# TODO

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Notes: variable description table *(write your answer here)*
#
# Fill in one row per variable:
#
# | Variable | Type (rating/category/id) | Range or values | What it means |
# |---|---|---|---|
# | trust | rating |Not trustworthy/Trustworthy|How trustworthy the homepage appears to the viewer |
# | aesthetics |rating|Ugly/Beautiful |How visually appealing the homepage looks |
# | usability |rating |Easy/Difficult to use| How easy the homepage looks to use, before actually using it|
# | prototypicality |rating | Disagree/Agree (1–7 Likert)|How much the homepage looks like a typical example of its category |
# | category | category| fashion / homeware / banks / universities|Which website domain the homepage belongs to |
#
# **Dataset report (3-4 sentences): how many homepages, how many users, how were the scores collected?**

# %% [markdown]
# ## Week 3 - Exploratory data analysis (EDA)
#
# **Goal:** describe the rating distributions, compare website categories, and measure how trust, aesthetics, usability, and prototypicality relate to each other.
#
# **Deliverables:** an EDA notebook section and an initial findings report.

# %%
# Plot the distribution of each rating.
# TODO

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)

# %%
# Compare the ratings across website categories.
# TODO

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)

# %%
# How strongly do the four ratings relate to each other?
# TODO

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Notes: initial findings *(write your answer here)*
#
# - Which rating is highest on average? Which is lowest?
# Typicality was highest on average, while trust was the lowest on average
# - Which website category is trusted most? Least?
# Bank is trusted most, University is trusted the least
# - Which two ratings are most strongly correlated, and does that make sense?
# Trust and Typicality. It does make sense that these two ratings are most strongly correlated, because users decide the credibility of a website based on how well it fits their schema of that kind of website

# %% [markdown]
# ## Week 4 - Feature extraction from website screenshots
#
# **Goal:** turn each homepage screenshot into numbers that describe its visual design. This is *computational aesthetics*: color, layout, and complexity features.
#
# **Deliverables:** a feature dataset (one row per homepage).

# %%
# Load one screenshot and display it so you understand the input.
# TODO

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Write a function that extracts visual design features from one screenshot.
# TODO

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Run the feature extractor on every homepage and merge the features into the ratings table.
# TODO

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Week 5 - Data visualization and design analysis
#
# **Goal:** visualize the design features and compare high vs low rated pages.
#
# **Deliverables:** a visualization report and a feature insight summary.

# %%
# Do the visual features relate to the ratings?
# TODO

# %%
# Compare high-trust vs low-trust homepages on each design feature.
# TODO

# %% [markdown]
# ### Notes: feature insight summary *(write your answer here)*
#
# - Which design feature is most associated with high trust? With high aesthetics?
# - Do simpler (lower complexity) pages get higher ratings? What does the data show?

# %% [markdown]
# ## Week 6 - Baseline machine learning models
#
# **Goal:** train simple regression models that predict each rating from the design features. Start with a train/test split and simple models.
#
# **Deliverables:** baseline model results.

# %%
# Split the data into training and test sets.
# TODO

# %%
# Train baseline models for the 'trust' target and score them.
# TODO

# %% [markdown]
# ### Notes: baseline results *(write your answer here)*
#
# Record R2 and MAE for each model on the trust target. Which baseline is best so far?

# %% [markdown]
# ## Week 7 - Advanced machine learning models
#
# **Goal:** try ensemble models (Random Forest, Gradient Boosting) with cross-validation and light hyperparameter tuning.
#
# **Deliverables:** a performance comparison table.

# %%
# Train ensemble models for all targets and build a comparison table.
# TODO

# %% [markdown]
# ### Notes: model comparison *(write your answer here)*
#
# - Which model is best for each target?
# - Are some ratings easier to predict from visual features than others? Why might that be?

# %% [markdown]
# ## Week 8 - Explainable AI and feature importance
#
# **Goal:** find out which design features most strongly drive predicted trust, using feature importance (and SHAP if you can install it).
#
# **Research question:** Which design features most strongly influence perceived trust?
#
# **Deliverables:** a feature ranking report and interpretability visualizations.

# %%
# Fit your best model for 'trust' on all data and read its feature importances.
# TODO

# %%
# Partial dependence: show how predicted trust changes as a single design feature varies.
# TODO

# %%
# (Optional) SHAP values give per-feature contributions for each prediction.
# TODO

# %% [markdown]
# ### Notes: feature ranking *(write your answer here)*
#
# Rank the design features from most to least important for trust. Does this match what you saw in the Week 5 visualizations?

# %% [markdown]
# ## Week 9 - Interaction analysis
#
# **Goal:** test whether combinations of design features matter, e.g. complexity x prototypicality, colorfulness x trust, symmetry x usability.
#
# **Deliverables:** research findings and statistical evidence.

# %%
# Does the effect of one feature depend on another? Look at an interaction.
# TODO

# %%
# Test the three interactions from the plan with product-term regressions.
# TODO

# %% [markdown]
# ### Notes: interaction findings *(write your answer here)*
#
# - Which interaction did you test, and what did you expect from the literature?
# - Did the data support it? Point to the plot or the coefficient.

# %% [markdown]
# ## Week 10 - Final paper and presentation
#
# **Goal:** write up the project as a short research paper and prepare a presentation.
#
# **Paper structure:** 1. Introduction (motivation, research question) - 2. Related work - 3. Dataset (description, statistics) - 4. Methods (feature extraction, ML models) - 5. Results (prediction performance, feature importance) - 6. Discussion (implications, limitations) - 7. Future work (deep learning models, real-time evaluation tools, automated design recommendations) - 8. References.

# %% [markdown]
# ### Paper draft *(write your answer here)*
#
# Draft each section here. Pull your best figures from the cells above (rating distributions, feature-vs-rating heatmap, model comparison table, feature importance).
#
# **Abstract:**
#
# **1. Introduction:**
#
# **2. Related work:**
#
# **3. Dataset:**
#
# **4. Methods:**
#
# **5. Results:**
#
# **6. Discussion (implications + limitations):**
#
# **7. Future work:**
#
# **8. References:**

# %% [markdown]
# ### Presentation plan *(write your answer here)*
#
# List your slides (1 line each), e.g. problem -> dataset -> features -> models -> what drives trust -> limitations.
